# %% [markdown]
# # 03 — Client segmentation
# Synthetic client attributes (publish-safe) clustered into segments.

# %%
from wealth_lab.segmentation.synth_clients import make_synthetic_clients
from wealth_lab.segmentation.model import fit_segments, profile_segments

clients = make_synthetic_clients(800)
model, labels = fit_segments(clients, k=5)
profile_segments(clients, labels)
